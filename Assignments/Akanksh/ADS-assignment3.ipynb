# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'numpy'

# %%
data = pd.read_csv('Housing.csv')

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
data.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking furnishingstatus
# 540              no              no        2      unfurnished
# 541              no              no        0   semi-furnished
# 542              no              no        0      unfurnished
# 543              no              no        0        furnished
# 544              no              no        0      unfurnished

# %%
data.shape
# Out:
# (545, 12)

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %% [markdown]
# ## Univariate Analysis

# %%
data['furnishingstatus'].value_counts()
# Out:
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: furnishingstatus, dtype: int64

# %%
data_furnished = data.loc[data['furnishingstatus']=='furnished']
data_semi = data.loc[data['furnishingstatus']=='semi-furnished']
data_unfurnished = data.loc[data['furnishingstatus']=='unfurnished']

# %%
plt.plot(data_furnished['area'],np.zeros_like(data_furnished['area']),'o')
plt.plot(data_semi['area'],np.zeros_like(data_semi['area']),'o')
plt.plot(data_unfurnished['area'],np.zeros_like(data_unfurnished['area']),'o')
plt.xlabel('Area')
plt.legend(['Furnished','Semi-furnished','Unfurnished'])
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.FacetGrid(data,hue="furnishingstatus",size=6).map(plt.scatter,"area","price").add_legend();
plt.show()
# Out:
# C:\Users\zains\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(data,hue="furnishingstatus",height=8)

# %% [markdown]
# ## Descriptive Analytics

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.mean()
# Out:
# C:\Users\zains\AppData\Local\Temp/ipykernel_6704/531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\zains\AppData\Local\Temp/ipykernel_6704/4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64

# %%
data.mode()
# Out:
#      price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  3500000  6000.0       3.0        1.0      2.0      yes        no       no
# 1  4200000     NaN       NaN        NaN      NaN      NaN       NaN      NaN
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no              no      0.0   semi-furnished
# 1             NaN             NaN      NaN              NaN

# %%
data.var()
# Out:
# C:\Users\zains\AppData\Local\Temp/ipykernel_6704/445316826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# price        3.498544e+12
# area         4.709512e+06
# bedrooms     5.447383e-01
# bathrooms    2.524757e-01
# stories      7.525432e-01
# parking      7.423300e-01
# dtype: float64

# %%
data.std()
# Out:
# C:\Users\zains\AppData\Local\Temp/ipykernel_6704/2723740006.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# price        1.870440e+06
# area         2.170141e+03
# bedrooms     7.380639e-01
# bathrooms    5.024696e-01
# stories      8.674925e-01
# parking      8.615858e-01
# dtype: float64

# %% [markdown]
# ## Checking Missing values

# %%
data.isnull().any()
# Out:
# price               False
# area                False
# bedrooms            False
# bathrooms           False
# stories             False
# mainroad            False
# guestroom           False
# basement            False
# hotwaterheating     False
# airconditioning     False
# parking             False
# furnishingstatus    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# ## Checking and Handling Outliers

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
sns.boxplot(data['area'])
# Out:
# C:\Users\zains\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area'>

# %%
sns.histplot(data['area'])
# Out:
# <AxesSubplot:xlabel='area', ylabel='Count'>

# %%
print(data['area'].mean() + (3*(data['area'].std())))
print(data['area'].mean() - (3*(data['area'].std())))
# Out:
# 11660.964351930079
# -1359.8817831227389

# %%
data = data[data['area']<=11660.964]

# %%
sns.boxplot(data['area'])
# Out:
# C:\Users\zains\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area'>

# %% [markdown]
# ## Encoding

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             538 non-null    int64
#  1   area              538 non-null    int64
#  2   bedrooms          538 non-null    int64
#  3   bathrooms         538 non-null    int64
#  4   stories           538 non-null    int64
#  5   mainroad          538 non-null    object
#  6   guestroom         538 non-null    object
#  7   basement          538 non-null    object
#  8   hotwaterheating   538 non-null    object
#  9   airconditioning   538 non-null    object
#  10  parking           538 non-null    int64
#  11  furnishingstatus  538 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 54.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['mainroad']=le.fit_transform(data['mainroad'])
data['guestroom']=le.fit_transform(data['guestroom'])
data['basement']=le.fit_transform(data['basement'])
data['hotwaterheating']=le.fit_transform(data['hotwaterheating'])
data['airconditioning']=le.fit_transform(data['airconditioning'])
data['furnishingstatus']=le.fit_transform(data['furnishingstatus'])
# Out:
# C:\Users\zains\AppData\Local\Temp/ipykernel_6704/2170673043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['mainroad']=le.fit_transform(data['mainroad'])
# C:\Users\zains\AppData\Local\Temp/ipykernel_6704/2170673043.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['guestroom']=le.fit_transform(data['guestroom'])
# C:\Users\zains\AppData\Local\Temp/ipykernel_6704/2170673043.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             538 non-null    int64
#  1   area              538 non-null    int64
#  2   bedrooms          538 non-null    int64
#  3   bathrooms         538 non-null    int64
#  4   stories           538 non-null    int64
#  5   mainroad          538 non-null    int32
#  6   guestroom         538 non-null    int32
#  7   basement          538 non-null    int32
#  8   hotwaterheating   538 non-null    int32
#  9   airconditioning   538 non-null    int32
#  10  parking           538 non-null    int64
#  11  furnishingstatus  538 non-null    int32
# dtypes: int32(6), int64(6)
# memory usage: 42.0 KB

# %% [markdown]
# ## Splitting data into X and Y

# %%
y = data['price']
x = data.drop(columns=['price'])

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 538, dtype: int64

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_scaled = scaler.fit_transform(x)

# %%
x = pd.DataFrame(x_scaled,columns = x.columns)

# %%
x
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 0    0.588175       0.6   0.333333  0.666667       1.0        0.0       0.0
# 1    0.745158       0.6   1.000000  1.000000       1.0        0.0       0.0
# 2    0.847095       0.4   0.333333  0.333333       1.0        0.0       1.0
# 3    0.596330       0.6   0.333333  0.333333       1.0        0.0       1.0
# 4    0.588175       0.6   0.000000  0.333333       1.0        1.0       1.0
# ..        ...       ...        ...       ...       ...        ...       ...
# 533  0.137615       0.2   0.000000  0.000000       1.0        0.0       1.0
# 534  0.076453       0.4   0.000000  0.000000       0.0        0.0       0.0
# 535  0.200815       0.2   0.000000  0.000000       1.0        0.0       0.0
# 536  0.128440       0.4   0.000000  0.000000       0.0        0.0       0.0
# 537  0.224261       0.4   0.000000  0.333333       1.0        0.0       0.0
#
# ...

# %% [markdown]
# ## Train Test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# ## Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)

# %%
pred
# Out:
# array([ 4196928.48114439,  3140711.48914492,  4957481.16103385,
#         2816395.40180052,  2234388.04706687,  4337214.15640244,
#         2692894.57063236,  4762011.09419541,  4771636.64438213,
#         5625717.53070561,  4732966.12581134,  5581043.51855203,
#         2379029.86238604,  3465689.58087053,  5322250.81978071,
#         3987926.19460171,  2480681.78177303,  2666388.50096752,
#         2599727.98040143,  7789629.92451505,  5004526.67194247,
#         3370991.84148461,  6508255.33699391,  4850858.30706494,
#         6268824.95677325,  3077495.45490834,  3530488.2951004 ,
#         3781856.01910097,  7440327.14317491,  8432655.43325403,
#         3975890.45467555,  4839278.55931354,  5661895.63388243,
#         2968801.09963893,  6399849.97589481,  6079220.27031009,
#         3721271.40023529,  5149490.16178183,  4311955.26301423,
#         3417758.39667923,  6538592.44025469,  4678489.46470415,
#         4652842.31717508,  4891692.8054908 ,  6678247.26005109,
# ...

# %%
y_test
# Out:
# 177    5243000
# 475    2961000
# 201    4900000
# 423    3360000
# 541    1767150
#         ...
# 500    2660000
# 231    4690000
# 342    3850000
# 450    3150000
# 12     9310000
# Name: price, Length: 108, dtype: int64

# %% [markdown]
# ## Performance Metrics

# %%
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error, accuracy_score,confusion_matrix

# %%
error=y_test-pred
error
# Out:
# 177    1.046072e+06
# 475   -1.797115e+05
# 201   -5.748116e+04
# 423    5.436046e+05
# 541   -4.672380e+05
#            ...
# 500    8.946088e+04
# 231    1.470888e+06
# 342   -1.820903e+06
# 450   -8.254688e+05
# 12     2.688307e+06
# Name: price, Length: 108, dtype: float64

# %%
mean_squared_error(y_test,pred)
# Out:
# 1169390851179.4717

# %%
r2_score(y_test,pred)
# Out:
# 0.6204921268459557

# %%
mean_absolute_error(y_test,pred)
# Out:
# 844495.6302088759
